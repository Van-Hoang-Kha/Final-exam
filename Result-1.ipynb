# %%
import pandas as pd
df = pd.read_csv('text.csv')
del df["Unnamed: 0"]
df
# Out:
#            post_id                                               text  \
# 0     3.584168e+15  Post này là nơi để các bạn thỏa sức nêu ra ý k...
# 1     3.830260e+15  #8236_PCs\n"Em chào các anh chị sv của trường ...
# 2     3.826158e+15  #8235_PCs\n#Chuyện_tình_cảm\n""Chắc gì là con ...
# 3     3.815595e+15  #8234_PCs\n"Em chào anh/chị , năm nay em 2k3 c...
# 4     3.813705e+15  #8233_PCs\n1. "Cho mình hỏi xíu, đã có danh sá...
# ...            ...                                                ...
# 2344  1.953966e+15  #5887_PCs\n1. "Hello World"\n2. "Mons............
# 2345  1.953903e+15  #5886_PCs\n[GÓC MẤT NGỦ]\n1. 1 giờ sáng hơn...
# 2346  1.953850e+15  #5885_PCs\n1. "Góc cảnh giác !!!\nMình bị cướp...
# 2347  1.952386e+15  #1111_M\nBạn thường làm gì để bản thân b...
# 2348  1.952327e+15  #5883_PCs\n1. Sài Gòn nắng nóng mồ hôi chảy nh...
#
#                                               post_text shared_text  \
# ...

# %%
df["text"]
# Out:
# 0       Post này là nơi để các bạn thỏa sức nêu ra ý k...
# 1       #8236_PCs\n"Em chào các anh chị sv của trường ...
# 2       #8235_PCs\n#Chuyện_tình_cảm\n""Chắc gì là con ...
# 3       #8234_PCs\n"Em chào anh/chị , năm nay em 2k3 c...
# 4       #8233_PCs\n1. "Cho mình hỏi xíu, đã có danh sá...
#                               ...
# 2344    #5887_PCs\n1. "Hello World"\n2. "Mons............
# 2345    #5886_PCs\n[GÓC MẤT NGỦ]\n1. 1 giờ sáng hơn...
# 2346    #5885_PCs\n1. "Góc cảnh giác !!!\nMình bị cướp...
# 2347    #1111_M\nBạn thường làm gì để bản thân b...
# 2348    #5883_PCs\n1. Sài Gòn nắng nóng mồ hôi chảy nh...
# Name: text, Length: 2349, dtype: object

# %%
text = df["text"][300]
print(text)
# Out:
# #7947_PCs
# #tâm_sự_mùa_cơm_tró
# "Thi xong đợt 1 rồi tâm sự tý đi nào các chàng trai cô gái
# Ấn tượng đầu tiên của các bạn về người yêu hoặc crush của mình là gì ?
# - ấn tượng của tôi là nụ cười của cô ấy ngay lần đầu gặp mặt , nụ cười của cô ấy như ánh mặt trời tỏa nắng cả lớp học vậy đó
# From : 1 chàng trai cô đơn 😊"
# --------------------------------------------
# Nụ cười crush có ấm bằng nụ cười của Bác không???
# #V
# link gửi cfs:https://goo.gl/9VKhVU

# %%
def classifer(text):
    pos = ["xin info","thả thính","học chung","tốt","giàu","phát triển","theo học","quen nhau","thỏa sức","kinh nghiệm","cảm ơn","chào","điểm cao","nguyện vọng","học bổng","xin lỗi","vui","dễ thương","đẹp","yêu","thích","qua môn","tốt nghiệp","say nắng","môn học","giúp","hứng thú",]
    neg = ["cắm sừng","ế","giận","hận","chán","chia tay","thất tình","thất vọng","tệ","xấu","mất","không tốt","nghèo","hết","mệt","vi phạm","học lại","dịch","rớt","chưa tốt nghiệp","chửi","mượn","cải nhau","nóng","lạnh","quay xe","không","thiếu"]
    count_pos = 0
    count_neg = 0
    for i in range(len(pos)):
        if pos[i] in text:
            count_pos +=1
           
        elif neg[i] in text:
            count_neg += 1
            
    if count_pos > count_neg:
         result = "Bài viết tích cực"
    else: 
         result = "bài viết tiêu cực"
    return result

# %%
classifer(text)
# Out:
# 'bài viết tiêu cực'
